# %% [markdown]
# <div align="center">
# <h1>25 Pandas Coding Mistakes You Should Avoid</h1>
#
# </div>
# <div align="center">
# Link for the original video: https://youtu.be/_gaAoJBMJ_Q
# </div>

# %% [markdown]
# ### 1. Writing into csv with unnecessary index column

# %%
import pandas as pd
df = pd.read_csv('housing.csv')

# Using `index=False` avoids adding unnecassary 
# unnamed index column to the output csv file 
df.to_csv('output.csv', index=False)

# %% [markdown]
# ### 2. Using column names that include spaces

# %%
# It's preferable to avoid including spaces 
# in column names And use underscores instead
df['bedroom_percentage'] = df['total_bedrooms'] / df['total_rooms']

# The column becomes accessible via the dot synatx
df.bedroom_percentage
# Out:
# 0        0.228617
# 1        0.248497
# 2        0.241667
# 3        0.224517
# 4        0.224209
#            ...
# 16995    0.177718
# 16996    0.224777
# 16997    0.198356
# 16998    0.206587
# 16999    0.164835
# Name: bedroom_percentage, Length: 17000, dtype: float64

# %%
# And querying it, is now much easier
df.query('bedroom_percentage >= 0.7')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17       -114.65     32.79                21.0         44.0            33.0
# 2990     -117.79     35.21                 4.0          2.0             2.0
# 6119     -118.23     34.05                52.0        346.0           270.0
# 6193     -118.24     34.04                52.0        116.0           107.0
# 6380     -118.26     34.05                52.0         58.0            52.0
# 6478     -118.27     34.05                37.0        350.0           245.0
# 8188     -118.44     34.28                46.0         11.0            11.0
# 11653    -121.29     37.95                52.0        107.0            79.0
# 12282    -121.49     38.58                52.0        569.0           405.0
# 13206    -121.90     37.37                20.0         78.0            72.0
#
#        population  households  median_income  median_house_value  \
# 17           64.0        27.0         0.8571             25000.0
# 2990          6.0         2.0         2.3750            137500.0
# 6119        346.0       251.0         2.5313            225000.0
# 6193        171.0        92.0         1.0769            112500.0
# 6380         41.0        27.0         4.0972            500001.0
# 6478       1122.0       248.0         2.7634            137500.0
# 8188         24.0        13.0         2.8750            162500.0
# 11653       167.0        53.0         0.7917             22500.0
# 12282       509.0       367.0         0.9196            137500.0
# 13206       120.0        69.0         1.0938            187500.0
#
#        bedroom_percentage
# 17               0.750000
# 2990             1.000000
# 6119             0.780347
# 6193             0.922414
# 6380             0.896552
# 6478             0.700000
# 8188             1.000000
# 11653            0.738318
# 12282            0.711775
# 13206            0.923077

# %% [markdown]
# ### 3. Not leveraging the QUERY method

# %%
df.query('housing_median_age > 50 and median_income < 1')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1466     -117.19     32.75                52.0         25.0             5.0
# 1826     -117.27     34.12                52.0        954.0           246.0
# 2888     -117.75     34.06                52.0         62.0             9.0
# 6274     -118.25     34.05                52.0       2806.0          1944.0
# 6476     -118.27     34.05                52.0       1292.0           864.0
# 6631     -118.28     33.93                52.0        117.0            33.0
# 11130    -121.01     37.65                52.0        178.0            53.0
# 11649    -121.29     37.96                52.0        287.0           119.0
# 11652    -121.29     37.95                52.0        288.0            86.0
# 11653    -121.29     37.95                52.0        107.0            79.0
# 12282    -121.49     38.58                52.0        569.0           405.0
# 12430    -121.58     39.14                52.0        662.0           160.0
# 12934    -121.84     39.73                52.0        857.0           232.0
# 15299    -122.28     37.82                52.0       1489.0           335.0
# 15304    -122.28     37.81                52.0        386.0           164.0
# 15761    -122.41     37.80                52.0       3260.0          1535.0
# 16623    -122.72     38.44                52.0        188.0            62.0
# 16969    -124.17     40.80                52.0        661.0           316.0
#
#        population  households  median_income  median_house_value  \
# 1466         13.0         5.0         0.5360            162500.0
# 1826        943.0       256.0         0.8658             87500.0
# 2888         44.0        16.0         0.4999            112500.0
# 6274       2232.0      1605.0         0.6775            350000.0
# 6476       2081.0       724.0         0.9563            275000.0
# 6631         74.0        45.0         0.4999             90600.0
# 11130       152.0        62.0         0.4999             82500.0
# 11649       154.0        85.0         0.8738             75000.0
# 11652       272.0        54.0         0.6960             42500.0
# 11653       167.0        53.0         0.7917             22500.0
# 12282       509.0       367.0         0.9196            137500.0
# 12430       520.0       149.0         0.8928             55000.0
# 12934       520.0       198.0         0.9870            112500.0
# 15299       728.0       244.0         0.8172             85300.0
# 15304       346.0       155.0         0.8075            137500.0
# 15761      3260.0      1457.0         0.9000            500001.0
# 16623       301.0        72.0         0.9437            129200.0
# 16969       392.0       244.0         0.9570             60000.0
#
#        bedroom_percentage
# 1466             0.200000
# 1826             0.257862
# 2888             0.145161
# 6274             0.692801
# 6476             0.668731
# 6631             0.282051
# 11130            0.297753
# 11649            0.414634
# 11652            0.298611
# 11653            0.738318
# 12282            0.711775
# 12430            0.241692
# 12934            0.270712
# 15299            0.224983
# 15304            0.424870
# 15761            0.470859
# 16623            0.329787
# 16969            0.478064

# %% [markdown]
# ### 4.  Formulating query strings using string methods
#
# <div align="center">
# pandas queries can access external variables by simply using the `@` symbol before the variable instead of formatting them via string methods
# </div>

# %%
min_pop = 1000
min_income = 0.7

df.query('population > @min_pop and median_income > @min_income')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# 8        -114.59     33.61                34.0       4789.0          1175.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...          ...       ...                 ...          ...             ...
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 6          1841.0       633.0         2.6768             82400.0
# 8          3134.0      1056.0         2.1782             58400.0
# 10         2434.0       824.0         2.6797             86500.0
# ...           ...         ...            ...                 ...
# 16991      1343.0       479.0         2.4805             73200.0
# 16993      1152.0       435.0         3.0806            106700.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
#
#        bedroom_percentage
# 0                0.228617
# 1                0.248497
# 6                0.233918
# 8                0.245354
# 10               0.214114
# ...                   ...
# 16991            0.194998
# 16993            0.168151
# 16996            0.224777
# 16997            0.198356
# 16998            0.206587
#
# [10296 rows x 10 columns]

# %% [markdown]
# ### 5. Using the `inplace=True` paramter.

# %%
# It's preferable to explicitly overwrite modifications 
# As "inplace" is generally frowned upon and 
# Also could be removed in future versions.

df = df.fillna(0)

# %% [markdown]
# ### 6. Iterating over the rows when vectorization is an option

# %%
# Bad practice
for i, row in df.iterrows():
    if row['housing_median_age'] > 50:
        df.loc[i, 'is_old'] = True
    else:
        df.loc[i, 'is_old'] = False

# %%
# Good practice
df['is_old'] = df['housing_median_age'] > 50
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        bedroom_percentage  is_old
# 0                0.228617   False
# 1                0.248497   False
# 2                0.241667   False
# 3                0.224517   False
# 4                0.224209   False
# ...                   ...     ...
# 16995            0.177718    True
# 16996            0.224777   False
# 16997            0.198356   False
# 16998            0.206587   False
# 16999            0.164835    True
#
# [17000 rows x 11 columns]

# %% [markdown]
# ### 7. Using the `apply` method when vectorization is an option

# %%
# Bad practice
df['population_squared'] = df.apply(lambda row: row['population'] ** 2, axis=1)

# %%
# Good practice
df['population_squared'] = df['population']**2

# %% [markdown]
# ### 8. Treating a slice of a dataframe as if it was a new dataframe

# %%
# Bad practice
netflix_df = pd.read_csv('Netflix.csv')
netflix_df_new = netflix_df.query('release_year > 2010')

netflix_df_new['director_first_name'] = netflix_df_new['director'].str[-5:]
netflix_df_new
# Out:
# C:\Users\Yusuf\AppData\Local\Temp\ipykernel_15488\1364741236.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_df_new['director_first_name'] = netflix_df_new['director'].str[-5:]
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# 5      s1002    Movie                                  Blue Ruin
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 2          Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3            Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4                     NaN                                 David Attenborough
# 5         Jeremy Saulnier  Macon Blair, Devin Ratray, Amy Hargreaves, Kev...
# ...                   ...                                                ...
# 7782                  NaN                                                NaN
# 7783                  NaN  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Abdellatif Kechiche  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785          Woody Allen  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786         Alex Lehmann           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 0                     Brazil  14-Aug-20          2020  TV-MA         4
# 2                  Indonesia  05-Jan-19          2016  TV-PG       124
# 3              United States  01-Mar-16          2016      R        90
# 4             United Kingdom  03-Dec-18          2017   TV-G         1
# 5      United States, France  25-Feb-19          2013      R        90
# ...                      ...        ...           ...    ...       ...
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# 7783                   Japan  01-Sep-20          2017  TV-MA         2
# 7784  France, Belgium, Spain  26-Aug-16          2013  NC-17       180
# 7785           United States  08-Mar-19          2013  PG-13        98
# 7786           United States  06-Dec-16          2016  TV-MA        81
#
#                                                  genres  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 2           Dramas, International Movies, Sports Movies
# 3                                              Comedies
# 4     British TV Shows, Docuseries, Science & Nature TV
# 5                         Independent Movies, Thrillers
# ...                                                 ...
# 7782                 International TV Shows, Reality TV
# 7783               Anime Series, International TV Shows
# 7784   Dramas, Independent Movies, International Movies
# 7785               Comedies, Dramas, Independent Movies
# 7786        Dramas, Independent Movies, Romantic Movies
#
#                                             description director_first_name
# 0     In a future where the elite inhabit an island ...                 NaN
# 2     Three Indonesian women break records by becomi...               oseno
# 3     New NFL star Thad buys his old teammates' belo...               Spiro
# 4     This sequel to the award-winning nature series...                 NaN
# 5     Bad news from the past unhinges vagabond Dwigh...               lnier
# ...                                                 ...                 ...
# 7782  Ten master artists turn up the heat in glassbl...                 NaN
# 7783  Determined to throw off the curse of being Sat...                 NaN
# 7784  Determined to fall in love, 15-year-old Adele ...               hiche
# 7785  The high life leads to high anxiety for a fash...               Allen
# 7786  Two former high school sweethearts unexpectedl...               hmann
#
# [6437 rows x 13 columns]

# %%
# Good practice
netflix_df_new = netflix_df.query('release_year > 2010').copy()

netflix_df_new['director_first_name'] = netflix_df_new['director'].str[-5:]
netflix_df_new
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# 5      s1002    Movie                                  Blue Ruin
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 2          Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3            Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4                     NaN                                 David Attenborough
# 5         Jeremy Saulnier  Macon Blair, Devin Ratray, Amy Hargreaves, Kev...
# ...                   ...                                                ...
# 7782                  NaN                                                NaN
# 7783                  NaN  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Abdellatif Kechiche  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785          Woody Allen  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786         Alex Lehmann           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 0                     Brazil  14-Aug-20          2020  TV-MA         4
# 2                  Indonesia  05-Jan-19          2016  TV-PG       124
# 3              United States  01-Mar-16          2016      R        90
# 4             United Kingdom  03-Dec-18          2017   TV-G         1
# 5      United States, France  25-Feb-19          2013      R        90
# ...                      ...        ...           ...    ...       ...
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# 7783                   Japan  01-Sep-20          2017  TV-MA         2
# 7784  France, Belgium, Spain  26-Aug-16          2013  NC-17       180
# 7785           United States  08-Mar-19          2013  PG-13        98
# 7786           United States  06-Dec-16          2016  TV-MA        81
#
#                                                  genres  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 2           Dramas, International Movies, Sports Movies
# 3                                              Comedies
# 4     British TV Shows, Docuseries, Science & Nature TV
# 5                         Independent Movies, Thrillers
# ...                                                 ...
# 7782                 International TV Shows, Reality TV
# 7783               Anime Series, International TV Shows
# 7784   Dramas, Independent Movies, International Movies
# 7785               Comedies, Dramas, Independent Movies
# 7786        Dramas, Independent Movies, Romantic Movies
#
#                                             description director_first_name
# 0     In a future where the elite inhabit an island ...                 NaN
# 2     Three Indonesian women break records by becomi...               oseno
# 3     New NFL star Thad buys his old teammates' belo...               Spiro
# 4     This sequel to the award-winning nature series...                 NaN
# 5     Bad news from the past unhinges vagabond Dwigh...               lnier
# ...                                                 ...                 ...
# 7782  Ten master artists turn up the heat in glassbl...                 NaN
# 7783  Determined to throw off the curse of being Sat...                 NaN
# 7784  Determined to fall in love, 15-year-old Adele ...               hiche
# 7785  The high life leads to high anxiety for a fash...               Allen
# 7786  Two former high school sweethearts unexpectedl...               hmann
#
# [6437 rows x 13 columns]

# %% [markdown]
# ### 9. Creating multiple intermediate dataframes when transforming a dataframe

# %%
# Bad practice
netflix_df_out = netflix_df.query('release_year > 2010')
netflix_df_out2 = netflix_df_out.groupby(['rating'])[['duration']].mean()
netflix_df_out3 = netflix_df_out2.sort_values(by='duration')

netflix_df_out3
# Out:
#             duration
# rating
# TV-Y       20.292135
# TV-Y7      24.025751
# TV-G       47.104046
# TV-PG      54.191843
# TV-Y7-FV   57.333333
# TV-MA      60.786492
# TV-14      66.973667
# G          80.181818
# NR         88.578125
# PG         95.342657
# UR        103.000000
# R         103.543820
# PG-13     104.940299
# NC-17     125.000000

# %%
# Good practice

netflix_df_out = (netflix_df.query('release_year > 2010').
    groupby(['rating'])[['duration']].mean().sort_values(by='duration'))

netflix_df_out
# Out:
#             duration
# rating
# TV-Y       20.292135
# TV-Y7      24.025751
# TV-G       47.104046
# TV-PG      54.191843
# TV-Y7-FV   57.333333
# TV-MA      60.786492
# TV-14      66.973667
# G          80.181818
# NR         88.578125
# PG         95.342657
# UR        103.000000
# R         103.543820
# PG-13     104.940299
# NC-17     125.000000

# %% [markdown]
# ### 10. Not properly setting columns dtypes

# %%
# Each column in a pandas dataframe has a dtype
# When reading in a csv file, pandas will try to infer the dtype
# But sometimes it's not possible to infer the dtype correctly
# In such cases, we can explicitly specify the dtype

# Dates can be specified when reading in the csv file
netflix_df = pd.read_csv('Netflix.csv', parse_dates=['date_added'])

# Or after the csv file has been read in
netflix_df['date_added'] = pd.to_datetime(netflix_df['date_added'])

# %% [markdown]
# ### 11. Using a string value instead of a boolean

# %%
# Bad practice
netflix_df['after_2010'] = 'NO'
netflix_df.loc[netflix_df['release_year'] > 2010, 'after_2010'] = 'YES'
netflix_df

# Manual fix is to map the values
netflix_df['after_2010'] = netflix_df['after_2010'].map({'YES': True, 'NO': False})

# %%
# Good practice
netflix_df['before_2010'] = netflix_df['release_year'] <= 2010
netflix_df
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1            Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2          Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3            Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4                     NaN                                 David Attenborough
# ...                   ...                                                ...
# 7782                  NaN                                                NaN
# 7783                  NaN  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Abdellatif Kechiche  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785          Woody Allen  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786         Alex Lehmann           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 0                     Brazil 2020-08-14          2020  TV-MA         4
# 1                      India 2017-12-15          2008  TV-MA       143
# 2                  Indonesia 2019-01-05          2016  TV-PG       124
# 3              United States 2016-03-01          2016      R        90
# 4             United Kingdom 2018-12-03          2017   TV-G         1
# ...                      ...        ...           ...    ...       ...
# 7782                  Canada 2019-07-12          2019  TV-14         1
# 7783                   Japan 2020-09-01          2017  TV-MA         2
# 7784  France, Belgium, Spain 2016-08-26          2013  NC-17       180
# 7785           United States 2019-03-08          2013  PG-13        98
# 7786           United States 2016-12-06          2016  TV-MA        81
#
#                                                  genres  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1        Horror Movies, International Movies, Thrillers
# 2           Dramas, International Movies, Sports Movies
# 3                                              Comedies
# 4     British TV Shows, Docuseries, Science & Nature TV
# ...                                                 ...
# 7782                 International TV Shows, Reality TV
# 7783               Anime Series, International TV Shows
# 7784   Dramas, Independent Movies, International Movies
# 7785               Comedies, Dramas, Independent Movies
# 7786        Dramas, Independent Movies, Romantic Movies
#
#                                             description  after_2010  \
# 0     In a future where the elite inhabit an island ...        True
# 1     An architect and his wife move into a castle t...       False
# 2     Three Indonesian women break records by becomi...        True
# 3     New NFL star Thad buys his old teammates' belo...        True
# 4     This sequel to the award-winning nature series...        True
# ...                                                 ...         ...
# 7782  Ten master artists turn up the heat in glassbl...        True
# 7783  Determined to throw off the curse of being Sat...        True
# 7784  Determined to fall in love, 15-year-old Adele ...        True
# 7785  The high life leads to high anxiety for a fash...        True
# 7786  Two former high school sweethearts unexpectedl...        True
#
#       before_2010
# 0           False
# 1            True
# 2           False
# 3           False
# 4           False
# ...           ...
# 7782        False
# 7783        False
# 7784        False
# 7785        False
# 7786        False
#
# [7787 rows x 14 columns]

# %% [markdown]
# ### 12. Not leveraging pandas built-in plotting methods

# %%
ax = netflix_df.plot(kind='scatter', x='release_year', y='duration', figsize=(10, 6))

# %% [markdown]
# ### 13. Manually applying string methods

# %%
# Bad practice
netflix_df['director_first_name'] = netflix_df['director'].apply(lambda x: str(x).upper())

# %%
#Good practice
netflix_df['director_first_name'] = netflix_df['director'].str.upper()

# %% [markdown]
# ### 14. Repeating commonly used data transformations

# %%
# It's best practice to write pipelines as functions

# Example pipeline
def process_data(df):
    df['Time_Normalized'] = df['Time'] / df['Time'].mean()
    df['Place'] = df['Place'].str.lower()
    return df

dfw = pd.DataFrame({'Time': [1, 2, 3], 'Place': ['Dallas', 'Austin', 'Houston']})
dfw = process_data(dfw)
dfw
# Out:
#    Time    Place  Time_Normalized
# 0     1   dallas              0.5
# 1     2   austin              1.0
# 2     3  houston              1.5

# %% [markdown]
# ### 15. Manually renaming columns

# %%
# Bad practice

df = pd.DataFrame({'Time': [1, 2, 3], 'Place': ['A', 'B', 'C'], 'Value': [10, 20, 30]})
df.columns = ['time', 'place', 'value']

# %%
# Good practice

df = pd.DataFrame({'Time': [1, 2, 3], 'Place': ['A', 'B', 'C'], 'Value': [10, 20, 30]})
df = df.rename(columns={'Time': 'time', 'Place': 'place', 'Value': 'value'})

# %% [markdown]
# ### 16. Aggregating by groups manually

# %%
# Bad practice

df = pd.read_csv('Netflix.csv')
tv_shows = df.loc[df['type'] == 'TV Show']['duration'].mean()
movies = df.loc[df['type'] == 'Movie']['duration'].mean()
print(tv_shows, movies)
# Out:
# 1.7759336099585061 99.30797842663195

# %%
# Good practice

df = pd.read_csv('Netflix.csv')
df.groupby('type')['duration'].mean()
# Out:
# type
# Movie      99.307978
# TV Show     1.775934
# Name: duration, dtype: float64

# %% [markdown]
# ### 17. Looping to create aggregates instead of using `grouby().agg()` method

# %%
# Bad practice

import numpy as np

# Loop over the rows of the dataframe to apppend the durations to a list
durations_tv = []
durations_movies = []

for i, row in df.iterrows():
    if row['type'] == 'TV Show':
        durations_tv.append(int(row['duration']))
    else:
        durations_movies.append(int(row['duration']))
        
# Convert the list to a numpy array
durations_tv = np.array(durations_tv)
durations_movies = np.array(durations_movies)

# Calculate the mean
tv_shows = np.mean(durations_tv)
movies = np.mean(durations_movies)

print('Mean duration of TV shows: ', tv_shows)
print('Mean duration of movies: ', movies)

# Calculate the median
tv_shows = np.median(durations_tv)
movies = np.median(durations_movies)

print('Median duration of TV shows: ', tv_shows)
print('Median duration of movies: ', movies)

# Calculate the count
tv_shows = np.count_nonzero(durations_tv)
movies = np.count_nonzero(durations_movies)

print('Count of TV shows: ', tv_shows)
print('Count of movies: ', movies)
# Out:
# Mean duration of TV shows:  1.7759336099585061
# Mean duration of movies:  99.30797842663195
# Median duration of TV shows:  1.0
# Median duration of movies:  98.0
# Count of TV shows:  2410
# Count of movies:  5377

# %%
# Good practice

df = pd.read_csv('Netflix.csv')
df.groupby('type')['duration'].agg(['mean', 'median', 'count'])
# Out:
#               mean  median  count
# type
# Movie    99.307978    98.0   5377
# TV Show   1.775934     1.0   2410

# %% [markdown]
# ### 18. Looping to calculate how a value changes

# %%
# Bad practice

df = pd.read_csv('housing.csv')

for i in range(1, len(df)):
    df.loc[i, 'median_house_value_change'] = (
        (df.loc[i, 'median_house_value'] - df.loc[i-1, 'median_house_value']) / df.loc[i-1, 'median_house_value'])
    df.loc[i, 'median_house_value_diff'] = df.loc[i, 'median_house_value'] - df.loc[i-1, 'median_house_value']

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  \
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
#
#    median_house_value_change  median_house_value_diff
# 0                        NaN                      NaN
# 1                   0.197309                  13200.0
# 2                   0.069913                   5600.0
# 3                  -0.143524                 -12300.0
# 4                  -0.107629                  -7900.0

# %%
# Good practice

df = pd.read_csv('housing.csv')

df['pct_change'] = df['median_house_value'].pct_change()
df['diff'] = df['median_house_value'].diff()

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  pct_change  \
# 0      1015.0       472.0         1.4936             66900.0         NaN
# 1      1129.0       463.0         1.8200             80100.0    0.197309
# 2       333.0       117.0         1.6509             85700.0    0.069913
# 3       515.0       226.0         3.1917             73400.0   -0.143524
# 4       624.0       262.0         1.9250             65500.0   -0.107629
#
#       diff
# 0      NaN
# 1  13200.0
# 2   5600.0
# 3 -12300.0
# 4  -7900.0

# %% [markdown]
# ### 19. Saving large datasets to CSVs

# %%
# Saving dataframes to csv files is not the best way to store data
# It's better to use parquet, feather or pickle which are much more efficient

df = pd.read_csv('housing.csv')

df.to_parquet('housing.parquet')
df.to_feather('housing.feather')
df.to_pickle('housing.pkl')

# %% [markdown]
# ### 20. Not leveraging pandas conditional formatting

# %%
df = pd.read_csv('housing.csv')

df.style.background_gradient(cmap='Blues')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ### 21. Not using suffixes when merging two dataframes

# %%
# Bad practice

df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df2 = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [10, 11, 12, 13, 14]})

df3 = df1.merge(df2, on=['A'])
df3
# Out:
#    A  B_x  B_y
# 0  1    4   10
# 1  2    5   11
# 2  3    6   12

# %%
# Good practice

df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df2 = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [10, 11, 12, 13, 14]})

df3 = df1.merge(df2, on=['A'], suffixes=('_left', '_right'))
df3
# Out:
#    A  B_left  B_right
# 0  1       4       10
# 1  2       5       11
# 2  3       6       12

# %% [markdown]
# ### 22. Validating the merging of dataframes

# %%
# Good practice

df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df2 = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [10, 11, 12, 13, 14]})

df3 = df1.merge(df2, on=['A'], suffixes=('_left', '_right'), validate='one_to_one')

# validation options
# validate='one_to_one' will raise an error if there are duplicate values in the key column
# validate='one_to_many' will raise an error if there are duplicate values in the key column
# validate='many_to_one' will raise an error if there are duplicate values in the key column
# validate='many_to_many' will raise an error if there are duplicate values in the key column

df3
# Out:
#    A  B_left  B_right
# 0  1       4       10
# 1  2       5       11
# 2  3       6       12

# %% [markdown]
# ### 23. wrapping expression so they are readable

# %%
# To make the code more readable, it's better to write chained 
# Operations on separate lines surrounded by parentheses

df = pd.read_csv('Netflix.csv')

# Bad practice
df_agg = df.groupby(['type', 'country'])['duration'].min().reset_index().fillna(0).sort_values(by='duration')

# %%
# Good practice

df_agg = (
    df
    .groupby(['type', 'country'])['duration']
    .min()
    .reset_index()
    .fillna(0)
    .sort_values(by='duration')
)

# %% [markdown]
# ### 24. Not using categorical datatypes

# %%
# It's better to store categorical data as category dtype instead of strings

netflix_df['type'] = netflix_df['type'].astype('category')
netflix_df['type']
# Out:
# 0       TV Show
# 1         Movie
# 2         Movie
# 3         Movie
# 4       TV Show
#          ...
# 7782    TV Show
# 7783    TV Show
# 7784      Movie
# 7785      Movie
# 7786      Movie
# Name: type, Length: 7787, dtype: category
# Categories (2, object): ['Movie', 'TV Show']

# %% [markdown]
# ### 25. duplicating columns after concatenating

# %%
# To avoid duplicating columns after concatenation 

df = pd.read_csv('housing.csv')
df_double = pd.concat([df, df], axis=1)
df_double = df_double.loc[:,~df_double.columns.duplicated()].copy()
